# %%
# %%html
# <!DOCTYPE html>
# <html>
# <head>
# <title>Landing Page</title>
# <style>
# body{
#     margin:0;
#     font-family:Arial;
#     background:#f4f6fb;
# }
# .header{
#     background:#111827;
#     color:white;
#     padding:15px;
#     text-align:center;
#     font-size:22px;
# }
# .hero{
#     background:linear-gradient(to right,#6366f1,#3b82f6);
#     color:white;
#     text-align:center;
#     padding:60px 20px;
# }
# .hero h1{
#     font-size:40px;
# }
# .hero p{
#     font-size:18px;
# }
# .hero button{
#     padding:12px 25px;
#     border:none;
#     border-radius:5px;
#     cursor:pointer;
# }
# .section{
#     padding:40px;
#     text-align:center;
# }
# .cards{
#     display:flex;
#     justify-content:center;
#     gap:20px;
#     flex-wrap:wrap;
# }
# .card{
#     background:white;
#     width:250px;
#     padding:20px;
#     border-radius:10px;
#     box-shadow:0 4px 8px rgba(0,0,0,0.1);
# }
# .testimonial{
#     background:#e0e7ff;
# }
# .cta{
#     background:#111827;
#     color:white;
#     padding:40px;
# }
# .footer{
#     background:black;
#     color:white;
#     text-align:center;
#     padding:10px;
# }
# </style>
# </head>
#
# <body>
#
# <div class="header">My Product</div>
#
# <div class="hero">
#     <h1>Website Landing Page UI</h1>
#     <p>Conversion focused modern design</p>
#     <button>Get Started</button>
# </div>
#
# <div class="section">
#     <h2>Features</h2>
#     <div class="cards">
#         <div class="card">Fast Design</div>
#         <div class="card">Responsive UI</div>
#         <div class="card">Easy to Use</div>
#     </div>
# </div>
#
# <div class="section testimonial">
#     <h2>Testimonials</h2>
#     <p>Excellent user experience!</p>
# </div>
#
# <div class="cta">
#     <h2>Start Now</h2>
#     <p>Improve your design skills</p>
#     <button>Join</button>
# </div>
#
# <div class="footer">© 2025 Landing Page</div>
#
# </body>
# </html>
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Landing Page</title>
# <style>
# body{
#     margin:0;
#     font-family:Arial;
#     background:#f4f6fb;
# }
# .header{
#     background:#111827;
#     color:white;
#     padding:15px;
#     text-align:center;
#     font-size:22px;
# }
# .hero{
#     background:linear-gradient(to right,#6366f1,#3b82f6);
#     color:white;
#     text-align:center;
#     padding:60px 20px;
# }
# .hero h1{
#     font-size:40px;
# }
# .hero p{
#     font-size:18px;
# }
# .hero button{
#     padding:12px 25px;
#     border:none;
#     border-radius:5px;
#     cursor:pointer;
# }
# .section{
#     padding:40px;
#     text-align:center;
# }
# .cards{
#     display:flex;
#     justify-content:center;
#     gap:20px;
#     flex-wrap:wrap;
# }
# .card{
#     background:white;
#     width:250px;
#     padding:20px;
#     border-radius:10px;
#     box-shadow:0 4px 8px rgba(0,0,0,0.1);
# }
# .testimonial{
#     background:#e0e7ff;
# }
# .cta{
#     background:#111827;
# ...
